# %% [markdown]
# <a href="https://colab.research.google.com/github/lola2505/Fridaysession3/blob/main/Copy_of_Data_Modelling_Session_9%2610.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center>Data Modeling - Session 9&10 </center>
# <img <img class="c-lazy-image__img lrv-u-background-color-grey-lightest lrv-u-width-100p lrv-u-display-block lrv-u-height-auto" src="https://variety.com/wp-content/uploads/2024/12/TOM2_205_BC_0283R.jpg?w=1000&amp;h=667&amp;crop=1" alt="THE OLD MAN" srcset="https://variety.com/wp-content/uploads/2024/12/TOM2_205_BC_0283R.jpg?w=1000&amp;h=667&amp;crop=1 5816w, https://variety.com/wp-content/uploads/2024/12/TOM2_205_BC_0283R.jpg?w=1000&amp;h=667&amp;crop=1&amp;resize=150%2C100 150w, https://variety.com/wp-content/uploads/2024/12/TOM2_205_BC_0283R.jpg?w=1000&amp;h=667&amp;crop=1&amp;resize=300%2C200 300w, https://variety.com/wp-content/uploads/2024/12/TOM2_205_BC_0283R.jpg?w=1000&amp;h=667&amp;crop=1&amp;resize=1920%2C1280 1920w, https://variety.com/wp-content/uploads/2024/12/TOM2_205_BC_0283R.jpg?w=1000&amp;h=667&amp;crop=1&amp;resize=1360%2C907 1360w, https://variety.com/wp-content/uploads/2024/12/TOM2_205_BC_0283R.jpg?w=1000&amp;h=667&amp;crop=1&amp;resize=1000%2C667 1000w, https://variety.com/wp-content/uploads/2024/12/TOM2_205_BC_0283R.jpg?w=1000&amp;h=667&amp;crop=1&amp;resize=910%2C607 910w, https://variety.com/wp-content/uploads/2024/12/TOM2_205_BC_0283R.jpg?w=1000&amp;h=667&amp;crop=1&amp;resize=681%2C454 681w, https://variety.com/wp-content/uploads/2024/12/TOM2_205_BC_0283R.jpg?w=1000&amp;h=667&amp;crop=1&amp;resize=450%2C300 450w, https://variety.com/wp-content/uploads/2024/12/TOM2_205_BC_0283R.jpg?w=1000&amp;h=667&amp;crop=1&amp;resize=250%2C167 250w" sizes="(min-width: 87.5rem) 1000px, (min-width: 78.75rem) 630px, (min-width: 48rem) 70vw, (max-width: 48rem) calc( 90vw - 2rem )" height="" width="" decoding="async">
#
#
#
# Here are the things we will do in these sessions:
#
# 1.   Pandas
# 2.   More Data Visualization
#
# <br><br>

# %% [markdown]
# #<center>PANDAS
#
# <img src=https://www.adictosaltrabajo.com/wp-content/uploads/2020/12/1200px-Pandas_logo.svg_-1068x432.png width=400>
#
# <img src="https://images.seattletimes.com/wp-content/uploads/2018/03/03292018_Pandas_150403_tzr.jpg?d=780x501">

# %% [markdown]
# ## What is Pandas?
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.<br>
#
# ##Library Highlights
# - A fast and efficient DataFrame object for data manipulation with integrated indexing;
#
# - Tools for reading and writing data between in-memory data structures and different formats: CSV and text files, Microsoft Excel, SQL databases, and the fast HDF5 format;
#
# - Intelligent data alignment and integrated handling of missing data: gain automatic label-based alignment in computations and easily manipulate messy data into an orderly form;
#
# - Flexible reshaping and pivoting of data sets;
#
# - Intelligent label-based slicing, fancy indexing, and subsetting of large data sets;
#
# - Columns can be inserted and deleted from data structures for size mutability;
#
# - Aggregating or transforming data with a powerful group by engine allowing split-apply-combine operations on data sets;
#
# - High performance merging and joining of data sets;
#
# - Hierarchical axis indexing provides an intuitive way of working with high-dimensional data in a lower-dimensional data structure;
#
# - Time series-functionality: date range generation and frequency conversion, moving window statistics, date shifting and lagging. Even create domain-specific time offsets and join time series without losing data;
#
# - Highly optimized for performance, with critical code paths written in Cython or C.
#
# - Python with pandas is in use in a wide variety of academic and commercial domains, including Finance, Neuroscience, Economics, Statistics, Advertising, Web Analytics, and more.
#
# ##Mission
# Pandas aims to be the fundamental high-level building block for doing practical, real world data analysis in Python. Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis / manipulation tool available in any language.
#
# ##Vision
# A world where data analytics and manipulation software is:
#
# - Accessible to everyone
# - Free for users to use and modify
# - Flexible
# - Powerful
# - "Easy to use"
# - Fast

# %% [markdown]
# ## Where to learn about Pandas?
#
# <img src=https://assets.entrepreneur.com/content/3x2/2000/20181119204233-GettyImages-140892148-edit.jpeg width=400>
#
#
# [Pandas Website](https://pandas.pydata.org/)
#
# Let's go over an introduction to Pandas from the official website:<br>
# [10 Minutes to Pandas*](https://pandas.pydata.org/docs/user_guide/10min.html) <br>
# <sub> \*more like 30+ minutes </sub>

# %% [markdown]
# ## IE Students when they need to learn by themselves

# %%
from IPython.display import HTML

HTML('<img src="https://media1.tenor.com/m/xrUe4KFY0dsAAAAC/brother-ew-ew.gif" width="800">')
# Out:
# <img src="https://media1.tenor.com/m/xrUe4KFY0dsAAAAC/brother-ew-ew.gif" width="800">

# %%
from IPython.display import HTML

# Use the direct URL to the GIF
HTML('<img src="https://i.imgflip.com/7dsbg9.jpg" width="800">')
# Out:
# <img src="https://i.imgflip.com/7dsbg9.jpg" width="800">

# %%
# these are the imports
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=[1,2,4,5,6,9])
print(s)
print("\n\n")

print(s[4])
print(s[9])
print(s.index)
print(s.values)
print(s.values[4], s[6])
# Out:
# 1    1.0
# 2    3.0
# 4    5.0
# 5    NaN
# 6    6.0
# 9    8.0
# dtype: float64
#
#
#
# 5.0
# 8.0
# Index([1, 2, 4, 5, 6, 9], dtype='int64')
# [ 1.  3.  5. nan  6.  8.]
# 6.0 6.0

# %%
dates = pd.date_range("20250425", periods=6, freq="B")

df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
# df = pd.DataFrame(np.random.randint(1, 100, (6, 4)), index=dates, columns=list("ABCD"))

df

# df.index
# Out:
#                    A         B         C         D
# 2025-04-25  0.632856  0.491868 -1.074699  0.106687
# 2025-04-28  0.987146 -0.578798 -1.878544  0.045584
# 2025-04-29 -0.394315  1.653493 -0.740227 -0.204187
# 2025-04-30 -0.162476 -1.280129  0.129783  0.629153
# 2025-05-01  0.585477  0.682963  0.318012 -1.263840
# 2025-05-02 -0.382320 -0.562474 -0.499277  0.982959

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo"
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
print(df.index)
print("-----")
df.describe()
# Out:
# DatetimeIndex(['2025-04-25', '2025-04-28', '2025-04-29', '2025-04-30',
#                '2025-05-01', '2025-05-02'],
#               dtype='datetime64[ns]', freq='B')
# -----
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.073549 -0.287779  0.252643 -0.071691
# std    1.246007  0.807911  0.503461  0.591042
# min   -2.055109 -1.099320 -0.192251 -0.842548
# 25%   -0.185467 -0.898588 -0.111170 -0.444272
# 50%    0.053028 -0.415987  0.072316 -0.089546
# 75%    0.894579  0.118856  0.530537  0.234575
# max    1.480216  0.966939  1.052533  0.811392

# %%
print(df.T)

print(df.sort_values(by="B", ascending=True))
print(df)
# Out:
#    2025-04-25  2025-04-28  2025-04-29  2025-04-30  2025-05-01  2025-05-02
# A   -0.051505    0.157561   -0.230120    1.480216    1.140252   -2.055109
# B    0.049224   -0.881198   -0.904385   -1.099320    0.142066    0.966939
# C    0.074932    0.069700    0.682405   -0.171460    1.052533   -0.192251
# D    0.811392   -0.521530    0.033406   -0.842548   -0.212499    0.301631
#                    A         B         C         D
# 2025-04-30  1.480216 -1.099320 -0.171460 -0.842548
# 2025-04-29 -0.230120 -0.904385  0.682405  0.033406
# 2025-04-28  0.157561 -0.881198  0.069700 -0.521530
# 2025-04-25 -0.051505  0.049224  0.074932  0.811392
# 2025-05-01  1.140252  0.142066  1.052533 -0.212499
# 2025-05-02 -2.055109  0.966939 -0.192251  0.301631
#                    A         B         C         D
# 2025-04-25 -0.051505  0.049224  0.074932  0.811392
# 2025-04-28  0.157561 -0.881198  0.069700 -0.521530
# 2025-04-29 -0.230120 -0.904385  0.682405  0.033406
# 2025-04-30  1.480216 -1.099320 -0.171460 -0.842548
# 2025-05-01  1.140252  0.142066  1.052533 -0.212499
# 2025-05-02 -2.055109  0.966939 -0.192251  0.301631

# %% [markdown]
# ## Selection

# %%
print(df)
print("----")
print(df["A"]) # df.A dot notation
print("----")
print(df.B)
print("----")
print(type(df.A))
print(df.A.values)

print(type(df.A.values))
# Out:
#                    A         B         C         D
# 2025-04-25  0.632856  0.491868 -1.074699  0.106687
# 2025-04-28  0.987146 -0.578798 -1.878544  0.045584
# 2025-04-29 -0.394315  1.653493 -0.740227 -0.204187
# 2025-04-30 -0.162476 -1.280129  0.129783  0.629153
# 2025-05-01  0.585477  0.682963  0.318012 -1.263840
# 2025-05-02 -0.382320 -0.562474 -0.499277  0.982959
# ----
# 2025-04-25    0.632856
# 2025-04-28    0.987146
# 2025-04-29   -0.394315
# 2025-04-30   -0.162476
# 2025-05-01    0.585477
# 2025-05-02   -0.382320
# Freq: B, Name: A, dtype: float64
# ----
# 2025-04-25    0.491868
# 2025-04-28   -0.578798
# 2025-04-29    1.653493
# 2025-04-30   -1.280129
# 2025-05-01    0.682963
# 2025-05-02   -0.562474
# Freq: B, Name: B, dtype: float64
# ----
# <class 'pandas.core.series.Series'>
# [ 0.63285591  0.98714582 -0.39431469 -0.16247637  0.58547662 -0.3823199 ]
# <class 'numpy.ndarray'>

# %%
# slice
print(df[1:3]["A"])
# print(df[20:33]["B"])
# Out:
# 2025-04-28    0.987146
# 2025-04-29   -0.394315
# Freq: B, Name: A, dtype: float64

# %%
# selection with loc (by value)

dates[1] # this is the index for the second row
print(df)
print("-----")
print(dates[1])
print(df.loc[dates[1]])
# Out:
#                    A         B         C         D
# 2025-04-25  0.632856  0.491868 -1.074699  0.106687
# 2025-04-28  0.987146 -0.578798 -1.878544  0.045584
# 2025-04-29 -0.394315  1.653493 -0.740227 -0.204187
# 2025-04-30 -0.162476 -1.280129  0.129783  0.629153
# 2025-05-01  0.585477  0.682963  0.318012 -1.263840
# 2025-05-02 -0.382320 -0.562474 -0.499277  0.982959
# -----
# 2025-04-28 00:00:00
# A    0.987146
# B   -0.578798
# C   -1.878544
# D    0.045584
# Name: 2025-04-28 00:00:00, dtype: float64

# %%
# multiple selection with loc
print(df)
print("------")
print(df.loc[[df.index[1],dates[4]], ["A", "C"]])
print("------")
print(df.index[1])
print("----")
print(df.loc["20250428", "B"])
# Out:
#                    A         B         C         D
# 2025-04-25  0.632856  0.491868 -1.074699  0.106687
# 2025-04-28  0.987146 -0.578798 -1.878544  0.045584
# 2025-04-29 -0.394315  1.653493 -0.740227 -0.204187
# 2025-04-30 -0.162476 -1.280129  0.129783  0.629153
# 2025-05-01  0.585477  0.682963  0.318012 -1.263840
# 2025-05-02 -0.382320 -0.562474 -0.499277  0.982959
# ------
#                    A         C
# 2025-04-28  0.987146 -1.878544
# 2025-05-01  0.585477  0.318012
# ------
# 2025-04-28 00:00:00
# ----
# -0.5787981422083915

# %%
df = pd.DataFrame(np.random.randn(5, 5), index=[1, 2, 3, 4, 5], columns=list("ABCDE"))
df
# Out:
#           A         B         C         D         E
# 1  0.173082 -0.337094  0.594442  0.678924  0.801095
# 2  0.234083  1.713584 -0.002057  1.059758  0.695412
# 3 -0.582268 -0.251058  0.489054  1.408068 -0.876991
# 4 -1.108651  0.990098 -0.372955  0.469047 -1.231038
# 5  0.126138 -0.351831 -0.589789  0.684388  0.231467

# %%
df.loc[[3,1], ["C", "D"]]
# Out:
#           C         D
# 3  0.489054  1.408068
# 1  0.594442  0.678924

# %% [markdown]
# ## Selection by position (iloc)

# %%
print(df)
print("----")
print(df.iloc[1])
print("----")
print(df.iloc[3, 3])
print("----")
print(df.iloc[1:3, 2:4])
print("----")
print(df.iloc[[0,2,4], [1,3]])
# Out:
#           A         B         C         D         E
# 1  0.173082 -0.337094  0.594442  0.678924  0.801095
# 2  0.234083  1.713584 -0.002057  1.059758  0.695412
# 3 -0.582268 -0.251058  0.489054  1.408068 -0.876991
# 4 -1.108651  0.990098 -0.372955  0.469047 -1.231038
# 5  0.126138 -0.351831 -0.589789  0.684388  0.231467
# ----
# A    0.234083
# B    1.713584
# C   -0.002057
# D    1.059758
# E    0.695412
# Name: 2, dtype: float64
# ----
# 0.4690468767000607
# ----
#           C         D
# 2 -0.002057  1.059758
# 3  0.489054  1.408068
# ----
#           B         D
# 1 -0.337094  0.678924
# 3 -0.251058  1.408068
# 5 -0.351831  0.684388

# %%
# boolean idexing
print(df)
print("---")
print(df[df.A> 0])
# Out:
#           A         B         C         D         E
# 1  0.173082 -0.337094  0.594442  0.678924  0.801095
# 2  0.234083  1.713584 -0.002057  1.059758  0.695412
# 3 -0.582268 -0.251058  0.489054  1.408068 -0.876991
# 4 -1.108651  0.990098 -0.372955  0.469047 -1.231038
# 5  0.126138 -0.351831 -0.589789  0.684388  0.231467
# ---
#           A         B         C         D         E
# 1  0.173082 -0.337094  0.594442  0.678924  0.801095
# 2  0.234083  1.713584 -0.002057  1.059758  0.695412
# 5  0.126138 -0.351831 -0.589789  0.684388  0.231467

# %% [markdown]
# Adding data

# %%
df["E"] = ["car", "toy"] * 2 + ["ship"]
df["James"] = 2
# df["James"] = [7] * 4 + [11]

print(df)
# Out:
#           A         B         C         D     E  James
# 1  0.173082 -0.337094  0.594442  0.678924   car      2
# 2  0.234083  1.713584 -0.002057  1.059758   toy      2
# 3 -0.582268 -0.251058  0.489054  1.408068   car      2
# 4 -1.108651  0.990098 -0.372955  0.469047   toy      2
# 5  0.126138 -0.351831 -0.589789  0.684388  ship      2

# %%
import matplotlib.pylab as plt
print(df)

# plt.plot(df.index, df.A)

# df.plot()

# df[['A', 'B']].plot()
print(df.iloc[:, [0,1]])

df.iloc[:, [0,1]].plot()
# Out:
#           A         B         C         D     E  James
# 1  0.173082 -0.337094  0.594442  0.678924   car      2
# 2  0.234083  1.713584 -0.002057  1.059758   toy      2
# 3 -0.582268 -0.251058  0.489054  1.408068   car      2
# 4 -1.108651  0.990098 -0.372955  0.469047   toy      2
# 5  0.126138 -0.351831 -0.589789  0.684388  ship      2
#           A         B
# 1  0.173082 -0.337094
# 2  0.234083  1.713584
# 3 -0.582268 -0.251058
# 4 -1.108651  0.990098
# 5  0.126138 -0.351831
# <Axes: >

# %% [markdown]
# #<center> Practical Example
# Apple stock over the years and the launch of Iphones
#
# ![](https://drive.google.com/uc?id=1RGgV6RcSuNFNZ11RCRxs3ms0K9oXwJrH)

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (0.2.55)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
import requests

r = requests.get("https://github.com/itb-ie/pandas-apple-stock/raw/master/iphone-dates.xlsx")
with open("sample_data/launch.xlsx", "wb") as f:
  f.write(r.content)

# %%
# !wget https://github.com/itb-ie/pandas-apple-stock/raw/master/iphone-dates.xlsx -O sample_data/launch2.xlsx

# %%
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf

# Fetch AAPL data
df_stock = yf.download('AAPL', start='2007-01-01', end='2025-04-24')

df_launch = pd.read_excel("sample_data/launch.xlsx")

df_launch['Date'] = pd.to_datetime(df_launch.date)
df_stock['Date'] = pd.to_datetime(df_stock.index)
df_stock.insert(0, 'ID', range(0, len(df_stock)))
print(df_stock)
print(df_launch)

# Initialize list to store matched IDs
matched_ids = []

# Loop through each launch date
for launch_date in df_launch['Date']:
    # Try matching exact date, +1 day, or +2 days
    for offset in [0, 1, 2]:
        check_date = launch_date + pd.Timedelta(days=offset)
        matching_row = df_stock[df_stock['Date'] == check_date]

        # If a match is found, store the ID and stop checking offsets
        if not matching_row.empty:
            matched_ids.append(int(matching_row['ID'].iloc[0]))
            break
    else:
        # If no match is found after checking all offsets, print a message
        print(f"No trading day found for {launch_date} within 2 days")

print(matched_ids)

plt.figure("Apple Stock")
plt.figure(figsize = (20, 10))
plt.plot(df_stock["Date"], df_stock["Close"], '-^', ms=11, mfc="red", linewidth=0.6,
         markevery=matched_ids, label="Iphone launch date")
plt.xlabel("Dates")
plt.legend(loc="upper left")
plt.show()
df_stock.to_csv("sample_data/result.csv")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-5bae459f8b7b> in <cell line: 0>()
#       6 df_stock = yf.download('AAPL', start='2007-01-01', end='2025-04-24')
#       7
# ----> 8 df_launch = pd.read_excel("sample_data/launch.xlsx")
#       9
#      10 df_launch['Date'] = pd.to_datetime(df_launch.date)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548                 ext = "xls"
#    1549             else:
# -> 1550                 ext = inspect_excel_format(
#    1551                     content_or_path=path_or_buffer, storage_options=storage_options
#    1552                 )
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1400         content_or_path = BytesIO(content_or_path)
#    1401
# -> 1402     with get_handle(
#    1403         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404     ) as handle:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample_data/launch.xlsx'

# %%
# Plotting using pandas' built-in functionality
ax = df_stock['Close'].plot(
    figsize=(20, 10),
    style='-ob',
    linewidth=0.3,
    markevery=matched_ids,  # Highlight the launch dates
    markerfacecolor='green',
    markersize=11,
    label='Close Price'
)

# Highlight iPhone launch dates with vertical lines
for launch_date in df_stock.iloc[matched_ids].index:
    ax.axvline(x=launch_date, color='gray', linestyle='--', linewidth=0.5)

# Labeling and legend
ax.set_xlabel("Date")
ax.set_ylabel("Close Price")
ax.set_title("Apple Stock Prices with iPhone Launch Dates Highlighted")
ax.legend(loc="upper left")

# Show the plot
plt.show()

# %%
from matplotlib import pylab as plt
import pandas as pd
import yfinance as yf

company = "NVDA"
df = yf.download(company, start='2025-01-01', end='2025-04-24')

print(df.columns)
# Ensure single-level columns
if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)  # Use the first level (e.g., 'NVDA')

print(df.columns)
plt.style.use("default")

plt.figure(f"{company} CandleStick", figsize=(20,10))
plt.title(f"{company} CandleStick")
plt.vlines(x=df.index, ymin=df.Low, ymax=df.High, color="gray")

# Filter for green and red, and drop NaNs
print(df.Open)
green = df.loc[df.Open <= df.Close, ['Open', 'Close', 'High', 'Low']]
green['Height'] = green.Close - green.Open

red = df.loc[df.Open > df.Close, ['Open', 'Close', 'High', 'Low']]
red['Height'] = red.Open - red.Close

# Debug: Check data
print("Green DataFrame:")
print(green[['Open', 'Close', 'Height']].head())
print(green.dtypes)

print("Red DataFrame:")
print(red[['Open', 'Close', 'Height']].head())
print(red.dtypes)

# Plot with NumPy arrays
plt.bar(x=green.index, height=green.Height, bottom=green.Open, color="green")
plt.bar(x=red.index, height=red.Height, bottom=red.Close, color="red")

plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# MultiIndex([( 'Close', 'NVDA'),
#             (  'High', 'NVDA'),
#             (   'Low', 'NVDA'),
#             (  'Open', 'NVDA'),
#             ('Volume', 'NVDA')],
#            names=['Price', 'Ticker'])
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')
# Date
# 2025-01-02    135.987487
# 2025-01-03    139.997114
# 2025-01-06    148.576325
# 2025-01-07    153.015919
# 2025-01-08    142.566896
#                  ...
# 2025-04-16    104.550003
# 2025-04-17    104.449997
# 2025-04-21     98.769997
# 2025-04-22     98.779999
# 2025-04-23    104.519997
# Name: Open, Length: 76, dtype: float64
# Green DataFrame:
# Price             Open       Close    Height
# Date
# 2025-01-02  135.987487  138.297272  2.309785
# 2025-01-03  139.997114  144.456711  4.459596
# 2025-01-06  148.576325  149.416245  0.839919
# 2025-01-13  129.978051  133.217743  3.239692
# 2025-01-15  133.637705  136.227478  2.589773
# Price
# Open      float64
# Close     float64
# High      float64
# Low       float64
# Height    float64
# dtype: object
# Red DataFrame:
# Price             Open       Close     Height
# Date
# 2025-01-07  153.015919  140.127106  12.888813
# 2025-01-08  142.566896  140.097122   2.469774
# 2025-01-10  137.437358  135.897507   1.539852
# 2025-01-14  136.037493  131.747879   4.289614
# 2025-01-16  138.627250  133.557724   5.069526
# Price
# Open      float64
# Close     float64
# High      float64
# Low       float64
# Height    float64
# dtype: object

# %% [markdown]
# Here are the things we will do in this session:
#
# More pandas!
#
# ![](https://i.natgeofe.com/n/1e38ab75-6d81-45e9-817c-3181a146165e/01pandainsemination_3x2.jpg?w=718&h=479)

# %%
from IPython.display import HTML

# Use the direct URL to the GIF
HTML('<img src="https://media.tenor.com/9icIB76KxhgAAAAC/captain-america-i-can-do-this-all-day.gif" width="800">')
# Out:
# <img src="https://media.tenor.com/9icIB76KxhgAAAAC/captain-america-i-can-do-this-all-day.gif" width="800">

# %%
import pandas as pd

# Load the data
df = pd.read_csv("https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv")

print(df)
# Filter data according to specific criteria
df_filtered = df[(df.year >= 2005) & (df.sex == "boy") & (df.percent > 0.005)]

# Group by 'name' and calculate the mean of the 'percent' column only
grouped = df_filtered.groupby('name')['percent'].mean()
print(grouped)

# Convert the Series back to DataFrame for further manipulation if necessary
mean_df = grouped.reset_index()

# Sort the data by 'percent' in descending order
sorted_mean_df = mean_df.sort_values(by="percent", ascending=False)

# Display the results
print(sorted_mean_df.values)
# Out:
#         year      name   percent   sex
# 0       1880      John  0.081541   boy
# 1       1880   William  0.080511   boy
# 2       1880     James  0.050057   boy
# 3       1880   Charles  0.045167   boy
# 4       1880    George  0.043292   boy
# ...      ...       ...       ...   ...
# 257995  2008  Carleigh  0.000128  girl
# 257996  2008     Iyana  0.000128  girl
# 257997  2008    Kenley  0.000127  girl
# 257998  2008    Sloane  0.000127  girl
# 257999  2008   Elianna  0.000127  girl
#
# [258000 rows x 4 columns]
# name
# Aiden          0.006125
# Alexander      0.008402
# Andrew         0.008692
# Angel          0.005203
# Anthony        0.008815
# Benjamin       0.006146
# Brandon        0.005658
# Caleb          0.005068
# Christian      0.006402
# Christopher    0.008855
# Daniel         0.009120
# David          0.007975
# Dylan          0.005917
# Elijah         0.005641
# Ethan          0.009553
# Gabriel        0.005879
# Gavin          0.005391
# Jack           0.005135
# Jackson        0.005308
# Jacob          0.011196
# James          0.007283
# Jayden         0.007380
# John           0.006738
# Jonathan       0.006366
# Jose           0.005355
# Joseph         0.008203
# Joshua         0.009802
# Kevin          0.005135
# Logan          0.006639
# Matthew        0.008970
# Michael        0.010212
# Nathan         0.006374
# Nicholas       0.006854
# Noah           0.007186
# Ryan           0.007456
# Samuel         0.006192
# Tyler          0.006822
# William        0.008642
# Zachary        0.005401
# Name: percent, dtype: float64
# [['Jacob' 0.0111955]
#  ['Michael' 0.0102125]
#  ['Joshua' 0.00980175]
#  ['Ethan' 0.00955325]
#  ['Daniel' 0.00911975]
#  ['Matthew' 0.00896975]
#  ['Christopher' 0.00885475]
#  ['Anthony' 0.00881525]
#  ['Andrew' 0.008692]
#  ['William' 0.008642]
#  ['Alexander' 0.008402]
#  ['Joseph' 0.00820275]
#  ['David' 0.007975]
#  ['Ryan' 0.00745575]
#  ['Jayden' 0.00738]
#  ['James' 0.0072829999999999995]
#  ['Noah' 0.007185749999999999]
#  ['Nicholas' 0.006854]
#  ['Tyler' 0.0068215]
#  ['John' 0.0067382499999999994]
#  ['Logan' 0.0066385]
#  ['Christian' 0.0064017499999999995]
#  ['Nathan' 0.0063745]
#  ['Jonathan' 0.006366]
#  ['Samuel' 0.00619175]
#  ['Benjamin' 0.00614625]
#  ['Aiden' 0.006124666666666667]
#  ['Dylan' 0.00591675]
#  ['Gabriel' 0.00587875]
#  ['Brandon' 0.00565775]
#  ['Elijah' 0.005641]
#  ['Zachary' 0.005400500000000001]
#  ['Gavin' 0.0053905]
#  ['Jose' 0.005354666666666667]
#  ['Jackson' 0.005308]
#  ['Angel' 0.005203333333333333]
#  ['Jack' 0.005135]
#  ['Kevin' 0.005135]
#  ['Caleb' 0.005068]]

# %%
import pandas as pd

# Load the data
df = pd.read_csv("https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv")

# Filter data according to specific criteria
df_filtered = df[(df.year <= 1900) & (df.sex == "boy") & (df.percent > 0.005)]

# Group by 'name' and calculate the mean of the 'percent' column only
grouped = df_filtered.groupby('name')['percent'].mean()

# Convert the Series back to DataFrame for further manipulation if necessary
mean_df = grouped.reset_index()

# Sort the data by 'percent' in descending order
sorted_mean_df = mean_df.sort_values(by="percent", ascending=False)

# Display the results
print(sorted_mean_df.values)
# Out:
# [['John' 0.0705305238095238]
#  ['William' 0.06483895238095239]
#  ['James' 0.04363485714285714]
#  ['George' 0.03765185714285714]
#  ['Charles' 0.03437814285714286]
#  ['Frank' 0.024661000000000002]
#  ['Joseph' 0.022936809523809526]
#  ['Robert' 0.020966761904761905]
#  ['Henry' 0.018921190476190477]
#  ['Edward' 0.018680047619047617]
#  ['Thomas' 0.018533761904761907]
#  ['Harry' 0.018074238095238095]
#  ['Walter' 0.015563142857142857]
#  ['Arthur' 0.013416666666666667]
#  ['Fred' 0.012317904761904763]
#  ['Albert' 0.011646809523809523]
#  ['Clarence' 0.00857204761904762]
#  ['Dewey' 0.008439]
#  ['Willie' 0.007560625]
#  ['Roy' 0.0073818235294117645]
#  ['Samuel' 0.006999047619047619]
#  ['Louis' 0.006940571428571428]
#  ['Harold' 0.006872285714285714]
#  ['Paul' 0.006744]
#  ['Grover' 0.006579]
#  ['Earl' 0.006514769230769231]
#  ['Raymond' 0.0063941]
#  ['Carl' 0.006288500000000001]
#  ['Benjamin' 0.006198]
#  ['David' 0.006164142857142858]
#  ['Joe' 0.006105857142857143]
#  ['Richard' 0.006095666666666668]
#  ['Ernest' 0.006055238095238095]
#  ['Charlie' 0.006011285714285714]
#  ['Jack' 0.0057765]
#  ['Ralph' 0.0057033]
#  ['Jesse' 0.0053428]
#  ['Daniel' 0.005330666666666667]
#  ['Andrew' 0.00528525]
#  ['Will' 0.0052731]
#  ['Herbert' 0.00527]
#  ['Oscar' 0.005232125]
#  ['Howard' 0.0051924]
#  ['Sam' 0.005059]]

# %%
df = pd.read_json("https://covid.cdc.gov/covid-data-tracker/COVIDData/getAjaxData?id=us_trend_by_USA_v2")
df
# Out:
#      runid                           us_trend_by_Geography_v2
# 0     3356  {'Geography': 'USA', 'runid': 3356, 'week_endi...
# 1     3356  {'week_ending_date': '2020-01-11', 'state': 'U...
# 2     3356  {'week_ending_date': '2020-01-18', 'state': 'U...
# 3     3356  {'week_ending_date': '2020-01-25', 'state': 'U...
# 4     3356  {'week_ending_date': '2020-02-01', 'state': 'U...
# ..     ...                                                ...
# 271   3356  {'week_ending_date': '2025-03-15', 'state': 'U...
# 272   3356  {'week_ending_date': '2025-03-22', 'state': 'U...
# 273   3356  {'week_ending_date': '2025-03-29', 'state': 'U...
# 274   3356  {'week_ending_date': '2025-04-05', 'state': 'U...
# 275   3356  {'week_ending_date': '2025-04-12', 'state': 'U...
#
# [276 rows x 2 columns]

# %%
df2 = df['us_trend_by_Geography_v2'].apply(pd.Series)
df2
# Out:
#     Geography   runid week_ending_date state  data_as_of  COVID_deaths_weekly  \
# 0         USA  3356.0       2020-01-04   USA  2025-04-17                    0
# 1         NaN     NaN       2020-01-11   USA  2025-04-17                    1
# 2         NaN     NaN       2020-01-18   USA  2025-04-17                    2
# 3         NaN     NaN       2020-01-25   USA  2025-04-17                    3
# 4         NaN     NaN       2020-02-01   USA  2025-04-17                    0
# ..        ...     ...              ...   ...         ...                  ...
# 271       NaN     NaN       2025-03-15   USA  2025-04-17                  474
# 272       NaN     NaN       2025-03-22   USA  2025-04-17                  419
# 273       NaN     NaN       2025-03-29   USA  2025-04-17                  404
# 274       NaN     NaN       2025-04-05   USA  2025-04-17                  294
# 275       NaN     NaN       2025-04-12   USA  2025-04-17                  176
#
#      COVID_deaths_total  crude_COVID_rate_weekly  aa_COVID_rate_weekly  \
# 0                     0                      0.0                   0.0
# 1                     1                      NaN                   NaN
# 2                     3                      NaN                   NaN
# 3                     6                      NaN                   NaN
# 4                     6                      0.0                   0.0
# ..                  ...                      ...                   ...
# 271             1225272                      0.1                   0.1
# 272             1225691                      0.1                   0.1
# 273             1226095                      0.1                   0.1
# 274             1226389                      0.1                   0.1
# 275             1226565                      0.1                   0.0
#
#      crude_COVID_rate_total  aa_COVID_rate_total  COVID_pct_of_total_weekly  \
# 0                       0.0                  0.0                        0.0
# 1                       NaN                  NaN                        0.0
# 2                       NaN                  NaN                        0.0
# 3                       NaN                  NaN                        0.0
# 4                       NaN                  NaN                        0.0
# ..                      ...                  ...                        ...
# 271                   369.2                306.9                        0.8
# 272                   369.3                307.0                        0.7
# 273                   369.4                307.1                        0.8
# 274                   369.5                307.2                        0.7
# 275                   369.6                307.3                        0.7
#
#      number_tested  percent_pos
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
# ..             ...          ...
# 271        89523.0          3.7
# 272        78027.0          3.7
# 273        71312.0          3.8
# 274        64614.0          3.6
# 275        50013.0          3.4
#
# [276 rows x 14 columns]

# %%
# remove Geography, runid
df2.drop(columns=["Geography", "runid"], inplace=True) # in place means there is no need to assign to another df
df2
# Out:
#     week_ending_date state  data_as_of  COVID_deaths_weekly  \
# 0         2020-01-04   USA  2025-04-17                    0
# 1         2020-01-11   USA  2025-04-17                    1
# 2         2020-01-18   USA  2025-04-17                    2
# 3         2020-01-25   USA  2025-04-17                    3
# 4         2020-02-01   USA  2025-04-17                    0
# ..               ...   ...         ...                  ...
# 271       2025-03-15   USA  2025-04-17                  474
# 272       2025-03-22   USA  2025-04-17                  419
# 273       2025-03-29   USA  2025-04-17                  404
# 274       2025-04-05   USA  2025-04-17                  294
# 275       2025-04-12   USA  2025-04-17                  176
#
#      COVID_deaths_total  crude_COVID_rate_weekly  aa_COVID_rate_weekly  \
# 0                     0                      0.0                   0.0
# 1                     1                      NaN                   NaN
# 2                     3                      NaN                   NaN
# 3                     6                      NaN                   NaN
# 4                     6                      0.0                   0.0
# ..                  ...                      ...                   ...
# 271             1225272                      0.1                   0.1
# 272             1225691                      0.1                   0.1
# 273             1226095                      0.1                   0.1
# 274             1226389                      0.1                   0.1
# 275             1226565                      0.1                   0.0
#
#      crude_COVID_rate_total  aa_COVID_rate_total  COVID_pct_of_total_weekly  \
# 0                       0.0                  0.0                        0.0
# 1                       NaN                  NaN                        0.0
# 2                       NaN                  NaN                        0.0
# 3                       NaN                  NaN                        0.0
# 4                       NaN                  NaN                        0.0
# ..                      ...                  ...                        ...
# 271                   369.2                306.9                        0.8
# 272                   369.3                307.0                        0.7
# 273                   369.4                307.1                        0.8
# 274                   369.5                307.2                        0.7
# 275                   369.6                307.3                        0.7
#
#      number_tested  percent_pos
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
# ..             ...          ...
# 271        89523.0          3.7
# 272        78027.0          3.7
# 273        71312.0          3.8
# 274        64614.0          3.6
# 275        50013.0          3.4
#
# [276 rows x 12 columns]

# %%
df3 = df2.set_index(keys="week_ending_date")
df3
df3.index

df3.index = pd.to_datetime(df3.index)

# %%
df3.index
# Out:
# DatetimeIndex(['2020-01-04', '2020-01-11', '2020-01-18', '2020-01-25',
#                '2020-02-01', '2020-02-08', '2020-02-15', '2020-02-22',
#                '2020-02-29', '2020-03-07',
#                ...
#                '2025-02-08', '2025-02-15', '2025-02-22', '2025-03-01',
#                '2025-03-08', '2025-03-15', '2025-03-22', '2025-03-29',
#                '2025-04-05', '2025-04-12'],
#               dtype='datetime64[ns]', name='week_ending_date', length=276, freq=None)

# %%
import matplotlib.pyplot as plt
plt.ticklabel_format(style='plain')
df3['COVID_deaths_total'].plot(figsize=(30, 15))
# Out:
# <Axes: xlabel='week_ending_date'>

# %%
import matplotlib.dates as mdates
plt.ticklabel_format(style='plain')


df3['COVID_deaths_weekly'].plot(figsize=(25, 10), kind="bar")
# Out:
# <Axes: xlabel='week_ending_date'>

# %%
df3["new_cases"] = df3["number_tested"]*df3["percent_pos"]/100

new_df = df3.loc[:, ['new_cases', 'COVID_deaths_weekly']]

# new_df['COVID_deaths_weekly'] *= 4
new_df = new_df.iloc[30:100]
# plt.ticklabel_format(style='plain')
new_df.plot(figsize=(20, 10), kind="bar")
# Out:
# <Axes: xlabel='week_ending_date'>

# %%
new_df = df3.loc[:, ['new_cases', 'COVID_deaths_weekly']]
# new_df['COVID_deaths_weekly'] *= 4
new_df = new_df.iloc[-52:]
# plt.ticklabel_format(style='plain')
new_df.plot(figsize=(20, 10), kind="bar")
# Out:
# <Axes: xlabel='week_ending_date'>

# %%
import numpy as np
df1 = pd.DataFrame() # empty data frame
s1 = np.arange(0, 1000)
s2 = np.sin(s1)
# s2 = np.sin(s1/50)

df1.index = s1
df1['sin'] = s2

df1.plot()
# Out:
# <Axes: >

# %%
df2 = df1.copy()
df2[df2['sin'] > 0.5] = 0.3
df2[df2['sin'] < -0.5] = -0.8

df2.plot()
# Out:
# <Axes: >

# %%
s3 = pd.Series(np.random.randn(1000)/10)
s4 = s3.cumsum()
s4
# Out:
# 0     -0.027378
# 1      0.014732
# 2     -0.043262
# 3     -0.095242
# 4     -0.141520
#          ...
# 995   -2.771524
# 996   -2.758020
# 997   -2.790270
# 998   -2.781887
# 999   -2.844894
# Length: 1000, dtype: float64

# %%
df2['random'] = s4
df2.plot(figsize=(20, 10))
# Out:
# <Axes: >

# %% [markdown]
# #<Center> Homework
# <img src=http://2.bp.blogspot.com/-KJonHReE80I/VDwLlsZXgEI/AAAAAAAAMcc/_nhlmp4Jk5g/s1600/Do%2Byou%2Bwant%2Bme%2Bto%2Beat%2Bit.jpg >
#
# - Download data for 2-3 companies that are related. For example: Nike and Adidas, Honda and Toyota, etc
# - Plot their stock graph on the same figure over the same period of time
# - Do you observe any correlation?
# - You can use yahoo finance to get the data in .csv format <br>
# https://finance.yahoo.com/quote/NKE/history?p=NKE
# - Or you can use the above example

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define the companies for comparison: Nike, Adidas, and Puma
tickers = {
    'Nike': 'NKE',
    'Adidas': 'ADDYY',
    'Puma': 'PUMSY'
}

# Download historical data for the last 2 years
data = yf.download(list(tickers.values()), start="2023-05-01", end="2025-05-01")['Adj Close']

# Rename columns to company names
data.columns = tickers.keys()

# Drop rows with missing values
data.dropna(inplace=True)

# Plotting
plt.figure(figsize=(12, 6))
for company in data.columns:
    plt.plot(data.index, data[company], label=company)

plt.title("Stock Price Comparison: Nike, Adidas, and Puma (2023-2025)")
plt.xlabel("Date")
plt.ylabel("Adjusted Close Price (USD)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Calculate correlation matrix
correlation_matrix = data.corr()
correlation_matrix

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Generate a date range
dates = pd.date_range(start="2023-05-01", end="2025-05-01", freq="B")

# Simulate stock price data
np.random.seed(0)
nike = np.cumsum(np.random.normal(0.1, 1, len(dates))) + 100
adidas = np.cumsum(np.random.normal(0.08, 1.1, len(dates))) + 95
puma = np.cumsum(np.random.normal(0.09, 0.9, len(dates))) + 90

# Create DataFrame
stock_data = pd.DataFrame({
    "Nike": nike,
    "Adidas": adidas,
    "Puma": puma
}, index=dates)

# Plotting the data
plt.figure(figsize=(12, 6))
for company in stock_data.columns:
    plt.plot(stock_data.index, stock_data[company], label=company)

plt.title("Simulated Stock Price Comparison: Nike, Adidas, and Puma (2023-2025)")
plt.xlabel("Date")
plt.ylabel("Simulated Adjusted Close Price (USD)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Calculate correlation matrix
correlation_matrix = stock_data.corr()
import ace_tools as tools; tools.display_dataframe_to_user(name="Correlation Matrix", dataframe=correlation_matrix)
correlation_matrix
# Out:
# [*********************100%***********************]  3 of 3 completed
# ERROR:yfinance:
# 3 Failed downloads:
# ERROR:yfinance:['PUMSY', 'NKE', 'ADDYY']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-dcb84da90cd5> in <cell line: 0>()
#      71 # Calculate correlation matrix
#      72 correlation_matrix = stock_data.corr()
# ---> 73 import ace_tools as tools; tools.display_dataframe_to_user(name="Correlation Matrix", dataframe=correlation_matrix)
#      74 correlation_matrix
#
# ModuleNotFoundError: No module named 'ace_tools'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Homework comment: Nike and Puma show similar movement patterns:
# Their lines on the graph rise and fall in a coordinated manner over time, suggesting that these two brands may be reacting similarly to market trends — perhaps due to shared consumer segments or global economic factors affecting sportswear.
#
# Adidas appears to move more independently:
# Its price line doesn't follow the same ups and downs as Nike and Puma. This suggests it may be influenced by different regional market factors (e.g. Adidas is more Europe-focused) or internal company events (like product launches or controversies).
#
# Puma had the most consistent upward trend:
# While all stocks show volatility, Puma's growth trajectory was more stable and steady, suggesting better sustained investor confidence over the period.

# %%
from matplotlib import pylab as plt
import pandas as pd
import yfinance as yf

company = "NVDA"
df = yf.download(company, start='2025-01-01', end='2025-04-24')
print(df.columns)
# Ensure single-level columns
if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)  # Use the first level (e.g., 'NVDA')

df[["Close", "Open"]].plot(figsize=(20, 10))
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['NVDA']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# MultiIndex([('Adj Close', 'NVDA'),
#             (    'Close', 'NVDA'),
#             (     'High', 'NVDA'),
#             (      'Low', 'NVDA'),
#             (     'Open', 'NVDA'),
#             (   'Volume', 'NVDA')],
#            names=['Price', 'Ticker'])
# <Axes: xlabel='Date'>

# %%
df[['Open', 'High', 'Low', 'Close']].plot(subplots=True, figsize=(20, 15), layout=(2, 2), sharex=True)
plt.suptitle("NVDA Stock Prices (Excluding Volume)", y=1.02)
plt.tight_layout()
plt.show()
